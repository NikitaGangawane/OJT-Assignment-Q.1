# %% [markdown]
# # Q1. Data Visualization and Statistical Measures:
# For this question, you are required to analyse the iris dataset (iris.csv) using Python. Perform all
# possible data visualization techniques (histograms, scatter plots, box plots, etc.) on all numerical
# columns of the dataset. Additionally, calculate all possible statistical measures (mean, median,
# mode, standard deviation, etc.) for each numerical column.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/pavla/Downloads/Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# Histograms for numerical columns
df.hist(figsize=(10, 8))
plt.suptitle("Histograms of Numerical Columns", y=0.95)
plt.show()

# %%
# Box plots for numerical columns
plt.figure(figsize=(10, 8))
sns.boxplot(data=df)
plt.title("Box Plots of Numerical Columns")
plt.show()

# %%
# Scatter plots for numerical columns
plt.figure(figsize=(10, 8))
sns.pairplot(df, kind="scatter")
plt.suptitle("Pairwise Scatter Plots of Numerical Columns", y=1.02)
plt.show()
# Out:
# C:\Users\pavla\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
print("SepalLength Mean:",df["SepalLengthCm"].mean())
print('')
print("SepalLength Median:",df["SepalLengthCm"].median())
print('')
print("SepalLength Mode:",df["SepalLengthCm"].mode())
print('')
print("SepalLength std:",df["SepalLengthCm"].std())
# Out:
# SepalLength Mean: 5.843333333333334
#
# SepalLength Median: 5.8
#
# SepalLength Mode: 0    5.0
# Name: SepalLengthCm, dtype: float64
#
# SepalLength std: 0.8280661279778629

# %%
print("SepalWidth Mean:",df["SepalWidthCm"].mean())
print('')
print("SepalWidth Median:",df["SepalWidthCm"].median())
print('')
print("SepalWidth Mode:",df["SepalWidthCm"].mode())
print('')
print("SepalWidth std:",df["SepalWidthCm"].std())
# Out:
# SepalWidth Mean: 3.0540000000000003
#
# SepalWidth Median: 3.0
#
# SepalWidth Mode: 0    3.0
# Name: SepalWidthCm, dtype: float64
#
# SepalWidth std: 0.4335943113621737

# %%
print("PetalLength Mean:",df["PetalLengthCm"].mean())
print('')
print("PetalLength Median:",df["PetalLengthCm"].median())
print('')
print("PetalLength Mode:",df["PetalLengthCm"].mode())
print('')
print("PetalLength std:",df["PetalLengthCm"].std())
# Out:
# PetalLength Mean: 3.758666666666666
#
# PetalLength Median: 4.35
#
# PetalLength Mode: 0    1.5
# Name: PetalLengthCm, dtype: float64
#
# PetalLength std: 1.7644204199522617

# %%
print("PetalWidth Mean:",df["PetalWidthCm"].mean())
print('')
print("PetalWidth Median:",df["PetalWidthCm"].median())
print('')
print("PetalWidth Mode:",df["PetalWidthCm"].mode())
print('')
print("PetalWidth std:",df["PetalWidthCm"].std())
# Out:
# PetalWidth Mean: 1.1986666666666668
#
# PetalWidth Median: 1.3
#
# PetalWidth Mode: 0    0.2
# Name: PetalWidthCm, dtype: float64
#
# PetalWidth std: 0.7631607417008414

# %%
print(df.describe())
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
